# %% [markdown]
# ## Code Block 0

# %%
#Clone master code repo
# !pip install torch-lr-finder
# !pip install grad-cam
# !git clone https://github.com/gharshit/ERA_MasterCodes.git
import os
os.chdir('/content/ERA_MasterCodes')
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), 1.21 KiB | 621.00 KiB/s, done.
# From https://github.com/gharshit/ERA_MasterCodes
#    5fe77cd..1bca4e4  main       -> origin/main
# Updating 5fe77cd..1bca4e4
# Fast-forward
#  Utils/utils.py |  3 +++
#  main.py        | 13 +++++--------
#  2 files changed, 8 insertions(+), 8 deletions(-)

# %%
############# To show the modular structure #############
from Utils.utils import list_files
list_files('/content/ERA_MasterCodes')
# Out:
# ERA_MasterCodes/
#     README.md
#     main.py
#     __init__.py
#     Train/
#         train_ocp.py
#         __init__.py
#     Utils/
#         utils.py
#         __init__.py
#     Models/
#         resnet.py
#         customresnet_a10.py
#         __init__.py
#     DataLoader/
#         data_loader_cifar10.py
#         __init__.py

# %% [markdown]
# ## Code Block 1

# %%
# %run main.py
# Out:
# Device set to:  cuda
# Hyperparamaters & Methods Initialzed...
#
# Files already downloaded and verified
# Testing data loaded successfully. Shape of data:  (10000, 32, 32, 3)
# Files already downloaded and verified
# Training data loaded successfully. Shape of data:  (50000, 32, 32, 3)
# Dataset loaded...

# %% [markdown]
# ## Code Block 2

# %%
# Initialize the model
S11assignment.loadmymodel()
# Out:
# Model Initialized. Below is the summary...
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
# ...

# %% [markdown]
# ## Code Block 3

# %%
# Set up the optimizer
S11assignment.giveoptimizer()

# Set loss criterion
S11assignment.giveloss()

# Set LR scheduler and get MAXLR
S11assignment.LRfinder()
# Out:
# Optimizer has been set to ADAM...
# Loss evaluated through Cross Entropy...
#   0%|          | 0/200 [00:00<?, ?it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 1.59E-02

# %% [markdown]
# ## Code Block 4

# %%
# # Set One Cycle Policy
S11assignment.scheduleOCP(1.59E-02)

# Train the model
S11assignment.runmymodel()
# Out:
# One Cycle Policy Activated...
# Current Epoch: 1 // Learning rate achieved at last epoch: [0.0002]
# Train: Loss=1.3672 Batch_id=97 Accuracy=42.06: 100%|██████████| 98/98 [00:20<00:00,  4.81it/s]
# Test set: Average loss: 0.0052, Accuracy: 3720/10000 (37.20%)
#
# Current Epoch: 2 // Learning rate achieved at last epoch: [0.0017]
# Train: Loss=1.0954 Batch_id=97 Accuracy=55.82: 100%|██████████| 98/98 [00:20<00:00,  4.80it/s]
# Test set: Average loss: 0.0065, Accuracy: 3124/10000 (31.24%)
#
# Current Epoch: 3 // Learning rate achieved at last epoch: [0.0056]
# Train: Loss=0.9391 Batch_id=97 Accuracy=62.22: 100%|██████████| 98/98 [00:20<00:00,  4.83it/s]
# Test set: Average loss: 0.0046, Accuracy: 4527/10000 (45.27%)
#
# Current Epoch: 4 // Learning rate achieved at last epoch: [0.0105]
# Train: Loss=0.8951 Batch_id=97 Accuracy=66.82: 100%|██████████| 98/98 [00:20<00:00,  4.85it/s]
# Test set: Average loss: 0.0018, Accuracy: 6773/10000 (67.73%)
#
# ...

# %% [markdown]
# ## Code Block 5

# %%
############# Plot LR at each epoch ##################

# Create a simple line plot
plt.plot(S11assignment.epochlr)

# Add labels and title
plt.xlabel("Iterations")
plt.ylabel("Learning Rate")
plt.title("Epoch level LR-OCP")

# Show the plot
plt.show()

# %%
# Plot accuracy plots
S11assignment.modelplots()

# %%
############## Plot missclassfiend images #######################
S11assignment.missclassplots("Session 11")

# %%
############## Plot missclassfiend images #######################
S11assignment.showgramcam("Misclassified-Session 11")
